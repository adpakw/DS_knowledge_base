# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('CSE_student_performances.csv')

# %%
df.head()
# Out:
#    Age   Gender AcademicPerformance TakingNoteInClass DepressionStatus  \
# 0    23    male             Average                No        Sometimes
# 1    23    male           Excellent         Sometimes              Yes
# 2    24    Male             Average                No        Sometimes
# 3    20  Female                Good               Yes        Sometimes
# 4    24  Female             Average               Yes              Yes
#
#   FaceChallangesToCompleteAcademicTask LikePresentation  SleepPerDayHours  \
# 0                                  Yes              Yes                12
# 1                                   No              Yes                 8
# 2                            Sometimes               No                 8
# 3                                  Yes               No                 5
# 4                                  Yes              Yes                 5
#
#    NumberOfFriend LikeNewThings
# 0             NaN           Yes
# ...

# %%
df.describe()
# Out:
#             Age   SleepPerDayHours  NumberOfFriend
# count  99.000000         99.000000       95.000000
# mean   22.515152          6.717172       16.189474
# std     1.560767          1.738169       25.397811
# min    20.000000          4.000000        0.000000
# 25%    21.000000          5.000000        3.000000
# 50%    23.000000          7.000000        6.000000
# 75%    24.000000          8.000000       15.000000
# max    25.000000         12.000000      100.000000

# %%
df_unique = df.drop_duplicates()

# %%
df_unique.head()
# Out:
#    Age   Gender AcademicPerformance TakingNoteInClass DepressionStatus  \
# 0    23    male             Average                No        Sometimes
# 1    23    male           Excellent         Sometimes              Yes
# 2    24    male             Average                No        Sometimes
# 3    20  female                Good               Yes        Sometimes
# 4    24  female             Average               Yes              Yes
#
#   FaceChallangesToCompleteAcademicTask LikePresentation  SleepPerDayHours  \
# 0                                  Yes              Yes                12
# 1                                   No              Yes                 8
# 2                            Sometimes               No                 8
# 3                                  Yes               No                 5
# 4                                  Yes              Yes                 5
#
#    NumberOfFriend LikeNewThings
# 0             NaN           Yes
# ...

# %%
df_unique.describe()
# Out:
#             Age   SleepPerDayHours  NumberOfFriend
# count  41.000000         41.000000       38.000000
# mean   22.609756          6.951220       17.947368
# std     1.447032          1.896724       28.218211
# min    20.000000          4.000000        0.000000
# 25%    21.000000          5.000000        3.000000
# 50%    23.000000          7.000000        6.500000
# 75%    24.000000          8.000000       14.250000
# max    25.000000         12.000000      100.000000

# %%
df_unique['Gender'] = df_unique['Gender'].str.lower()
# Out:
# /tmp/ipykernel_675/3982829721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique['Gender'] = df_unique['Gender'].str.lower()

# %%
df_unique['AcademicPerformance'] = df_unique['AcademicPerformance'].apply(lambda x: x.replace('Good', 'Goo'))
df_unique['AcademicPerformance'] = df_unique['AcademicPerformance'].apply(lambda x: x.replace('Goo', 'Good'))
# Out:
# /tmp/ipykernel_675/2759859701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique['AcademicPerformance'] = df_unique['AcademicPerformance'].apply(lambda x: x.replace('Good', 'Goo'))
# /tmp/ipykernel_675/2759859701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique['AcademicPerformance'] = df_unique['AcademicPerformance'].apply(lambda x: x.replace('Goo', 'Good'))

# %%
df_unique['AcademicPerformance'] = df_unique['AcademicPerformance'].apply(lambda x: 'Good' if x == 'Goo' else x)

# %%
df_unique.isnull()
# Out:
#      Age   Gender  AcademicPerformance  TakingNoteInClass  DepressionStatus  \
# 0   False   False                False              False             False
# 1   False   False                False              False             False
# 2   False   False                False              False             False
# 3   False   False                False              False             False
# 4   False   False                False              False             False
# 5   False   False                False              False             False
# 6   False   False                False              False             False
# 7   False   False                False              False             False
# 8   False   False                False              False             False
# 9   False   False                False              False             False
# 10  False   False                False              False             False
# ...

# %%
df_dropped = df_unique.dropna()
df_dropped.describe()
# Out:
#             Age   SleepPerDayHours  NumberOfFriend
# count  38.000000         38.000000       38.000000
# mean   22.631579          6.684211       17.947368
# std     1.478148          1.561449       28.218211
# min    20.000000          4.000000        0.000000
# 25%    21.000000          5.000000        3.000000
# 50%    23.000000          7.000000        6.500000
# 75%    24.000000          8.000000       14.250000
# max    25.000000         10.000000      100.000000

# %%
# df_filled = df_unique.fillna(0)

# %%
mean =

# %%
df_dropped['AcademicPerformance'].astype('category')
# Out:
# 1         Excellent
# 2           Average
# 3              Good
# 4           Average
# 5              Good
# 6              Good
# 7           Average
# 8         Excellent
# 9           Average
# 10          Average
# 11        Excellent
# 12          Average
# 13             Good
# 14    Below average
# 15          Average
# 16          Average
# 17             Good
# 18          Average
# 19             Good
# 20             Good
# 21             Good
# 22             Good
# 23             Good
# 25          Average
# 26             Good
# 27          Average
# 28          Average
# 29             Good
# 30          Average
# 31          Average
# 33        Excellent
# 38             Good
# 41          Average
# 45             Good
# 48          Average
# 50          Average
# 51             Good
# 58             Good
# Name: AcademicPerformance, dtype: category
# Categories (4, object): ['Average', 'Below average', 'Excellent', 'Good']

# %%
df_dropped['AcademicPerformance'] = pd.Categorical(df_dropped['AcademicPerformance'], categories=['Below average','Average','Good','Excellent'], ordered=True)
# Out:
# /tmp/ipykernel_675/3051420820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped['AcademicPerformance'] = pd.Categorical(df_dropped['AcademicPerformance'], categories=['Below average','Average','Good','Excellent'], ordered=True)

# %%
df_dropped.head()
# Out:
#    Age   Gender AcademicPerformance TakingNoteInClass DepressionStatus  \
# 1    23    male           Excellent         Sometimes              Yes
# 2    24    male             Average                No        Sometimes
# 3    20  female                Good               Yes        Sometimes
# 4    24  female             Average               Yes              Yes
# 5    23    male                Good         Sometimes        Sometimes
#
#   FaceChallangesToCompleteAcademicTask LikePresentation  SleepPerDayHours  \
# 1                                   No              Yes                 8
# 2                            Sometimes               No                 8
# 3                                  Yes               No                 5
# 4                                  Yes              Yes                 5
# 5                                   No              Yes                 8
#
#    NumberOfFriend LikeNewThings
# 1            80.0           Yes
# ...

# %%
df_dropped['AcademicPerformance'].cat.codes
# Out:
# 1     3
# 2     1
# 3     2
# 4     1
# 5     2
# 6     2
# 7     1
# 8     3
# 9     1
# 10    1
# 11    3
# 12    1
# 13    2
# 14    0
# 15    1
# 16    1
# 17    2
# 18    1
# 19    2
# 20    2
# 21    2
# 22    2
# 23    2
# 25    1
# 26    2
# 27    1
# 28    1
# 29    2
# 30    1
# 31    1
# 33    3
# 38    2
# 41    1
# 45    2
# 48    1
# 50    1
# 51    2
# 58    2
# dtype: int8
